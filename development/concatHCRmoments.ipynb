# %% [markdown]
# # concatHCRmoments
# This script combines multiple CF/Radial output files from the HIAPER Cloud Radar (HCR) into a single output netCDF file. The most comonly required variables for analysis are concatenated into single arrays, and the inclusion of additional variables is easy enough to do if desired.
# <br><br>
# Currently this has only been tested with 10hz moments files, though combining the 100hz moments files is not entirely out of the question.
# <br><br>
# _Written by Dan Stechman_
# <br>
# _University of Illinois at Urbana-Champaign_

# %%
from netCDF4 import Dataset
import numpy as np
import xarray as xr
from glob import glob
import time
import warnings
from datetime import datetime as dt
import pandas as pd

scriptStrtT = dt.now()

warnings.filterwarnings("ignore",category=RuntimeWarning)
# Out:
# /Users/danstechman/anaconda/lib/python3.5/site-packages/xarray/core/formatting.py:16: FutureWarning: The pandas.tslib module is deprecated and will be removed in a future version.
#   from pandas.tslib import OutOfBoundsDatetime

# %% [markdown]
# ## User Settings
# This is where the most commonly modified settings reside (i.e., flight, start/end times, input data path/filenames, output path/filename, etc.)

# %%
# This variable should match the name of the parent directory containing
#    the flight data for the given mission. Used in defining file input 
#    and output names.
flight = 'RF06_20180129'

# Specify start and end times to include in concatenated dataset
#    startT and endT should be strings of the format 'YYYYmmdd_HHMMSS'
#    Otherwise, set startT to 'beg' to use the first file in the whole flight directory
#    and/or set endT to 'end' to use the last file in the whole flight directory
# startT = '20180123_004500'
# endT = '20180123_011500'
startT = 'beg'
endT = 'end'

# Specify the location/name(s) of the input files and the output file
files = sorted(glob('/Volumes/SOCRATES_1/' + flight + '/HCR/cfradial/10hz_moments/cfrad.*HCR*.nc'))
outFileName = '/Volumes/SOCRATES_1/' + flight + '/HCR/' + flight + '_concat-HCR-moments.nc'

# These are the number of gates nearest the aircraft with negative gate range values (we throw these out)
#    **I've seen this number vary between projects, but seems consistent so far for SOCRATES at least
rGateStrt = 12

# %% [markdown]
# ## Data File ID
# Determine which data files will provide data between the user-defined start and end times

# %%
if startT == 'beg':
    strtFIx = 0
else:
    # Search string designed to grab cfradial files with the desired start times
    strtStr = '.' + startT
    
    # Get the index of the first occurence of cfradial file containing the 
    #     start string in its file name  
    strtFIx = ([ix for ix, f in enumerate(files) if strtStr in f])[0]
    
        
if endT == 'end':
    endFIx = len(files)-1
else:
    # Search string designed to grab cfradial files with the desired end times
    endStr = 'to_' + endT
    
    # Get the index of the first occurence of cfradial file containing the 
    #     end string in its file name
    endFIx = ([ix for ix, f in enumerate(files) if endStr in f])[0]
    


# Create an array of file indices (from our file listing) to loop over
# rFileIx = np.arange(210,220)
rFileIx = np.arange(strtFIx,endFIx)

# %% [markdown]
# ## Define output variables
# Loop through all of the input files and add up the total number of points in the time dimension and determine the number of gates (vertical dimension) after removing gates with negative ranges.
# <br><br>
# Then, create empty (zero-filled) arrays of the appropriate sizes for out output.

# %%
print('{}    Determining output dimensions...'.format(dt.strftime(dt.now(),'%y/%m/%d %H:%M:%S')))
totalTime = 0;
for rFile in rFileIx:
    radData = xr.open_dataset(files[rFile])
    totalTime += radData.dims['time']
totalRng = radData.dims['range'] - rGateStrt

print('\tTotal number of points in time dimension: {}'.format(totalTime))
print('\tTotal number of gates (in vertical dimension): {}'.format(totalRng))

time1d_all = np.zeros((totalTime,),dtype='datetime64[ns]')
radElev_all = np.zeros((totalTime,))
alt1d_all = np.zeros((totalTime,))
alt_all = np.zeros((totalTime,totalRng))
time_all = np.zeros((totalTime,totalRng),dtype='datetime64[ns]')
dbz_all = np.zeros((totalTime,totalRng))
vel_all = np.zeros((totalTime,totalRng))
width_all = np.zeros((totalTime,totalRng))
snr_all = np.zeros((totalTime,totalRng))
dbm_all = np.zeros((totalTime,totalRng))
ncp_all = np.zeros((totalTime,totalRng))
ldr_all = np.zeros((totalTime,totalRng))
# Out:
# 18/02/01 13:35:53    Determining output dimensions...
# 	Total number of points in time dimension: 309742
# 	Total number of gates (in vertical dimension): 758

# %% [markdown]
# ## Concatenate Variables Across All Files
# Loop through the files covering the requested time period and fill out output arrays.
# <br>
# Also, create modified time and altitude arrays which need to be 2-dimensional for plotting.
# <br>
# > The altitude array is modified using the gate range from the aircraft to yield ground-relative altitudes for each gate.

# %%
print('{}    Beginning file concatenation for {}...'.format(dt.strftime(dt.now(),'%y/%m/%d %H:%M:%S'),flight))
numFiles = len(rFileIx)
fileCount = 1
strtIx = 0
for rFile in rFileIx:
    print('\tAppending file {} of {}...'.format(fileCount,numFiles))
    
    # Open the current radar data file
    radData = xr.open_dataset(files[rFile])
    
    # Get length of time dimension of current file and define the end index
    #    of the array slice to place data within the output arrays
    endIx = radData.dims['time'] + strtIx
        
    # Pull out the dimension variables
    gateRange_1d = radData['range'].data[rGateStrt:]
    alt_1d = radData['altitude'].data
    time_1d = radData['time'].data
    
    # Get the beam elevation angle variable (used to determine upward/downward pointing)
    radElev_1d = radData.elevation.data
    
    # HCR elevation angle is positive when pointing upward
    # Adjust the gateRange variable if this is the case to properly initialize
    #    the ground-relative altitude array
    if np.all(radElev_1d > 0):
        gateRange_1d *= -1
    
    # Create arrays of gateRange and gate altitude matching dimensions of 2-D variables
    gateRange_2d = np.transpose(np.tile(gateRange_1d,(len(time_1d),1)))
    time_2d = np.tile(time_1d,(len(gateRange_1d),1))
    alt_2d = np.tile(alt_1d,(len(gateRange_1d),1))

    # Add data from current file into slice of output arrays
    alt_all[strtIx:endIx,:] = np.transpose(alt_2d - gateRange_2d) # ground-relative altitude MSL of each gate
    time_all[strtIx:endIx,:] = np.transpose(time_2d)
    
    time1d_all[strtIx:endIx] = time_1d[:]
    radElev_all[strtIx:endIx] = radElev_1d[:]
    
    alt1d_all[strtIx:endIx] = alt_1d[:]

    dbz_all[strtIx:endIx,:] = radData['DBZ'].data[:,rGateStrt:]
    vel_all[strtIx:endIx,:] = radData['VEL'].data[:,rGateStrt:]
    width_all[strtIx:endIx,:] = radData['WIDTH'].data[:,rGateStrt:]
    snr_all[strtIx:endIx,:] = radData['SNR'].data[:,rGateStrt:]
    dbm_all[strtIx:endIx,:] = radData['DBMHX'].data[:,rGateStrt:]
    ncp_all[strtIx:endIx,:] = radData['NCP'].data[:,rGateStrt:]
    ldr_all[strtIx:endIx,:] = radData['LDR'].data[:,rGateStrt:]
        
    # Move our starting index for the output array to immediately
    #    after the end of the current data slice
    strtIx = endIx
    
    fileCount += 1
# Out:
# 18/02/01 13:37:01    Beginning file concatenation for RF06_20180129...
# 	Appending file 1 of 524...
# 	Appending file 2 of 524...
# 	Appending file 3 of 524...
# 	Appending file 4 of 524...
# 	Appending file 5 of 524...
# 	Appending file 6 of 524...
# 	Appending file 7 of 524...
# 	Appending file 8 of 524...
# 	Appending file 9 of 524...
# 	Appending file 10 of 524...
# 	Appending file 11 of 524...
# 	Appending file 12 of 524...
# 	Appending file 13 of 524...
# 	Appending file 14 of 524...
# 	Appending file 15 of 524...
# 	Appending file 16 of 524...
# 	Appending file 17 of 524...
# 	Appending file 18 of 524...
# 	Appending file 19 of 524...
# 	Appending file 20 of 524...
# 	Appending file 21 of 524...
# 	Appending file 22 of 524...
# 	Appending file 23 of 524...
# 	Appending file 24 of 524...
# 	Appending file 25 of 524...
# 	Appending file 26 of 524...
# 	Appending file 27 of 524...
# 	Appending file 28 of 524...
# 	Appending file 29 of 524...
# 	Appending file 30 of 524...
# 	Appending file 31 of 524...
# 	Appending file 32 of 524...
# 	Appending file 33 of 524...
# 	Appending file 34 of 524...
# 	Appending file 35 of 524...
# 	Appending file 36 of 524...
# 	Appending file 37 of 524...
# 	Appending file 38 of 524...
# 	Appending file 39 of 524...
# 	Appending file 40 of 524...
# 	Appending file 41 of 524...
# 	Appending file 42 of 524...
# 	Appending file 43 of 524...
# 	Appending file 44 of 524...
# 	Appending file 45 of 524...
# 	Appending file 46 of 524...
# 	Appending file 47 of 524...
# 	Appending file 48 of 524...
# 	Appending file 49 of 524...
# 	Appending file 50 of 524...
# 	Appending file 51 of 524...
# 	Appending file 52 of 524...
# 	Appending file 53 of 524...
# 	Appending file 54 of 524...
# 	Appending file 55 of 524...
# 	Appending file 56 of 524...
# 	Appending file 57 of 524...
# 	Appending file 58 of 524...
# 	Appending file 59 of 524...
# 	Appending file 60 of 524...
# 	Appending file 61 of 524...
# 	Appending file 62 of 524...
# 	Appending file 63 of 524...
# 	Appending file 64 of 524...
# 	Appending file 65 of 524...
# 	Appending file 66 of 524...
# 	Appending file 67 of 524...
# 	Appending file 68 of 524...
# 	Appending file 69 of 524...
# 	Appending file 70 of 524...
# 	Appending file 71 of 524...
# 	Appending file 72 of 524...
# 	Appending file 73 of 524...
# 	Appending file 74 of 524...
# 	Appending file 75 of 524...
# 	Appending file 76 of 524...
# 	Appending file 77 of 524...
# 	Appending file 78 of 524...
# 	Appending file 79 of 524...
# 	Appending file 80 of 524...
# 	Appending file 81 of 524...
# 	Appending file 82 of 524...
# 	Appending file 83 of 524...
# 	Appending file 84 of 524...
# 	Appending file 85 of 524...
# 	Appending file 86 of 524...
# 	Appending file 87 of 524...
# 	Appending file 88 of 524...
# 	Appending file 89 of 524...
# 	Appending file 90 of 524...
# 	Appending file 91 of 524...
# 	Appending file 92 of 524...
# 	Appending file 93 of 524...
# 	Appending file 94 of 524...
# 	Appending file 95 of 524...
# 	Appending file 96 of 524...
# 	Appending file 97 of 524...
# 	Appending file 98 of 524...
# 	Appending file 99 of 524...
# 	Appending file 100 of 524...
# 	Appending file 101 of 524...
# 	Appending file 102 of 524...
# 	Appending file 103 of 524...
# 	Appending file 104 of 524...
# 	Appending file 105 of 524...
# 	Appending file 106 of 524...
# 	Appending file 107 of 524...
# 	Appending file 108 of 524...
# 	Appending file 109 of 524...
# 	Appending file 110 of 524...
# 	Appending file 111 of 524...
# 	Appending file 112 of 524...
# 	Appending file 113 of 524...
# 	Appending file 114 of 524...
# 	Appending file 115 of 524...
# 	Appending file 116 of 524...
# 	Appending file 117 of 524...
# 	Appending file 118 of 524...
# 	Appending file 119 of 524...
# 	Appending file 120 of 524...
# 	Appending file 121 of 524...
# 	Appending file 122 of 524...
# 	Appending file 123 of 524...
# 	Appending file 124 of 524...
# 	Appending file 125 of 524...
# 	Appending file 126 of 524...
# 	Appending file 127 of 524...
# 	Appending file 128 of 524...
# 	Appending file 129 of 524...
# 	Appending file 130 of 524...
# 	Appending file 131 of 524...
# 	Appending file 132 of 524...
# 	Appending file 133 of 524...
# 	Appending file 134 of 524...
# 	Appending file 135 of 524...
# 	Appending file 136 of 524...
# 	Appending file 137 of 524...
# 	Appending file 138 of 524...
# 	Appending file 139 of 524...
# 	Appending file 140 of 524...
# 	Appending file 141 of 524...
# 	Appending file 142 of 524...
# 	Appending file 143 of 524...
# 	Appending file 144 of 524...
# 	Appending file 145 of 524...
# 	Appending file 146 of 524...
# 	Appending file 147 of 524...
# 	Appending file 148 of 524...
# 	Appending file 149 of 524...
# 	Appending file 150 of 524...
# 	Appending file 151 of 524...
# 	Appending file 152 of 524...
# 	Appending file 153 of 524...
# 	Appending file 154 of 524...
# 	Appending file 155 of 524...
# 	Appending file 156 of 524...
# 	Appending file 157 of 524...
# 	Appending file 158 of 524...
# 	Appending file 159 of 524...
# 	Appending file 160 of 524...
# 	Appending file 161 of 524...
# 	Appending file 162 of 524...
# 	Appending file 163 of 524...
# 	Appending file 164 of 524...
# 	Appending file 165 of 524...
# 	Appending file 166 of 524...
# 	Appending file 167 of 524...
# 	Appending file 168 of 524...
# 	Appending file 169 of 524...
# 	Appending file 170 of 524...
# 	Appending file 171 of 524...
# 	Appending file 172 of 524...
# 	Appending file 173 of 524...
# 	Appending file 174 of 524...
# 	Appending file 175 of 524...
# 	Appending file 176 of 524...
# 	Appending file 177 of 524...
# 	Appending file 178 of 524...
# 	Appending file 179 of 524...
# 	Appending file 180 of 524...
# 	Appending file 181 of 524...
# 	Appending file 182 of 524...
# 	Appending file 183 of 524...
# 	Appending file 184 of 524...
# 	Appending file 185 of 524...
# 	Appending file 186 of 524...
# 	Appending file 187 of 524...
# 	Appending file 188 of 524...
# 	Appending file 189 of 524...
# 	Appending file 190 of 524...
# 	Appending file 191 of 524...
# 	Appending file 192 of 524...
# 	Appending file 193 of 524...
# 	Appending file 194 of 524...
# 	Appending file 195 of 524...
# 	Appending file 196 of 524...
# 	Appending file 197 of 524...
# 	Appending file 198 of 524...
# 	Appending file 199 of 524...
# 	Appending file 200 of 524...
# 	Appending file 201 of 524...
# 	Appending file 202 of 524...
# 	Appending file 203 of 524...
# 	Appending file 204 of 524...
# 	Appending file 205 of 524...
# 	Appending file 206 of 524...
# 	Appending file 207 of 524...
# 	Appending file 208 of 524...
# 	Appending file 209 of 524...
# 	Appending file 210 of 524...
# 	Appending file 211 of 524...
# 	Appending file 212 of 524...
# 	Appending file 213 of 524...
# 	Appending file 214 of 524...
# 	Appending file 215 of 524...
# 	Appending file 216 of 524...
# 	Appending file 217 of 524...
# 	Appending file 218 of 524...
# 	Appending file 219 of 524...
# 	Appending file 220 of 524...
# 	Appending file 221 of 524...
# 	Appending file 222 of 524...
# 	Appending file 223 of 524...
# 	Appending file 224 of 524...
# 	Appending file 225 of 524...
# 	Appending file 226 of 524...
# 	Appending file 227 of 524...
# 	Appending file 228 of 524...
# 	Appending file 229 of 524...
# 	Appending file 230 of 524...
# 	Appending file 231 of 524...
# 	Appending file 232 of 524...
# 	Appending file 233 of 524...
# 	Appending file 234 of 524...
# 	Appending file 235 of 524...
# 	Appending file 236 of 524...
# 	Appending file 237 of 524...
# 	Appending file 238 of 524...
# 	Appending file 239 of 524...
# 	Appending file 240 of 524...
# 	Appending file 241 of 524...
# 	Appending file 242 of 524...
# 	Appending file 243 of 524...
# 	Appending file 244 of 524...
# 	Appending file 245 of 524...
# 	Appending file 246 of 524...
# 	Appending file 247 of 524...
# 	Appending file 248 of 524...
# 	Appending file 249 of 524...
# 	Appending file 250 of 524...
# 	Appending file 251 of 524...
# 	Appending file 252 of 524...
# 	Appending file 253 of 524...
# 	Appending file 254 of 524...
# 	Appending file 255 of 524...
# 	Appending file 256 of 524...
# 	Appending file 257 of 524...
# 	Appending file 258 of 524...
# 	Appending file 259 of 524...
# 	Appending file 260 of 524...
# 	Appending file 261 of 524...
# 	Appending file 262 of 524...
# 	Appending file 263 of 524...
# 	Appending file 264 of 524...
# 	Appending file 265 of 524...
# 	Appending file 266 of 524...
# 	Appending file 267 of 524...
# 	Appending file 268 of 524...
# 	Appending file 269 of 524...
# 	Appending file 270 of 524...
# 	Appending file 271 of 524...
# 	Appending file 272 of 524...
# 	Appending file 273 of 524...
# 	Appending file 274 of 524...
# 	Appending file 275 of 524...
# 	Appending file 276 of 524...
# 	Appending file 277 of 524...
# 	Appending file 278 of 524...
# 	Appending file 279 of 524...
# 	Appending file 280 of 524...
# 	Appending file 281 of 524...
# 	Appending file 282 of 524...
# 	Appending file 283 of 524...
# 	Appending file 284 of 524...
# 	Appending file 285 of 524...
# 	Appending file 286 of 524...
# 	Appending file 287 of 524...
# 	Appending file 288 of 524...
# 	Appending file 289 of 524...
# 	Appending file 290 of 524...
# 	Appending file 291 of 524...
# 	Appending file 292 of 524...
# 	Appending file 293 of 524...
# 	Appending file 294 of 524...
# 	Appending file 295 of 524...
# 	Appending file 296 of 524...
# 	Appending file 297 of 524...
# 	Appending file 298 of 524...
# 	Appending file 299 of 524...
# 	Appending file 300 of 524...
# 	Appending file 301 of 524...
# 	Appending file 302 of 524...
# 	Appending file 303 of 524...
# 	Appending file 304 of 524...
# 	Appending file 305 of 524...
# 	Appending file 306 of 524...
# 	Appending file 307 of 524...
# 	Appending file 308 of 524...
# 	Appending file 309 of 524...
# 	Appending file 310 of 524...
# 	Appending file 311 of 524...
# 	Appending file 312 of 524...
# 	Appending file 313 of 524...
# 	Appending file 314 of 524...
# 	Appending file 315 of 524...
# 	Appending file 316 of 524...
# 	Appending file 317 of 524...
# 	Appending file 318 of 524...
# 	Appending file 319 of 524...
# 	Appending file 320 of 524...
# 	Appending file 321 of 524...
# 	Appending file 322 of 524...
# 	Appending file 323 of 524...
# 	Appending file 324 of 524...
# 	Appending file 325 of 524...
# 	Appending file 326 of 524...
# 	Appending file 327 of 524...
# 	Appending file 328 of 524...
# 	Appending file 329 of 524...
# 	Appending file 330 of 524...
# 	Appending file 331 of 524...
# 	Appending file 332 of 524...
# 	Appending file 333 of 524...
# 	Appending file 334 of 524...
# 	Appending file 335 of 524...
# 	Appending file 336 of 524...
# 	Appending file 337 of 524...
# 	Appending file 338 of 524...
# 	Appending file 339 of 524...
# 	Appending file 340 of 524...
# 	Appending file 341 of 524...
# 	Appending file 342 of 524...
# 	Appending file 343 of 524...
# 	Appending file 344 of 524...
# 	Appending file 345 of 524...
# 	Appending file 346 of 524...
# 	Appending file 347 of 524...
# 	Appending file 348 of 524...
# 	Appending file 349 of 524...
# 	Appending file 350 of 524...
# 	Appending file 351 of 524...
# 	Appending file 352 of 524...
# 	Appending file 353 of 524...
# 	Appending file 354 of 524...
# 	Appending file 355 of 524...
# 	Appending file 356 of 524...
# 	Appending file 357 of 524...
# 	Appending file 358 of 524...
# 	Appending file 359 of 524...
# 	Appending file 360 of 524...
# 	Appending file 361 of 524...
# 	Appending file 362 of 524...
# 	Appending file 363 of 524...
# 	Appending file 364 of 524...
# 	Appending file 365 of 524...
# 	Appending file 366 of 524...
# 	Appending file 367 of 524...
# 	Appending file 368 of 524...
# 	Appending file 369 of 524...
# 	Appending file 370 of 524...
# 	Appending file 371 of 524...
# 	Appending file 372 of 524...
# 	Appending file 373 of 524...
# 	Appending file 374 of 524...
# 	Appending file 375 of 524...
# 	Appending file 376 of 524...
# 	Appending file 377 of 524...
# 	Appending file 378 of 524...
# 	Appending file 379 of 524...
# 	Appending file 380 of 524...
# 	Appending file 381 of 524...
# 	Appending file 382 of 524...
# 	Appending file 383 of 524...
# 	Appending file 384 of 524...
# 	Appending file 385 of 524...
# 	Appending file 386 of 524...
# 	Appending file 387 of 524...
# 	Appending file 388 of 524...
# 	Appending file 389 of 524...
# 	Appending file 390 of 524...
# 	Appending file 391 of 524...
# 	Appending file 392 of 524...
# 	Appending file 393 of 524...
# 	Appending file 394 of 524...
# 	Appending file 395 of 524...
# 	Appending file 396 of 524...
# 	Appending file 397 of 524...
# 	Appending file 398 of 524...
# 	Appending file 399 of 524...
# 	Appending file 400 of 524...
# 	Appending file 401 of 524...
# 	Appending file 402 of 524...
# 	Appending file 403 of 524...
# 	Appending file 404 of 524...
# 	Appending file 405 of 524...
# 	Appending file 406 of 524...
# 	Appending file 407 of 524...
# 	Appending file 408 of 524...
# 	Appending file 409 of 524...
# 	Appending file 410 of 524...
# 	Appending file 411 of 524...
# 	Appending file 412 of 524...
# 	Appending file 413 of 524...
# 	Appending file 414 of 524...
# 	Appending file 415 of 524...
# 	Appending file 416 of 524...
# 	Appending file 417 of 524...
# 	Appending file 418 of 524...
# 	Appending file 419 of 524...
# 	Appending file 420 of 524...
# 	Appending file 421 of 524...
# 	Appending file 422 of 524...
# 	Appending file 423 of 524...
# 	Appending file 424 of 524...
# 	Appending file 425 of 524...
# 	Appending file 426 of 524...
# 	Appending file 427 of 524...
# 	Appending file 428 of 524...
# 	Appending file 429 of 524...
# 	Appending file 430 of 524...
# 	Appending file 431 of 524...
# 	Appending file 432 of 524...
# 	Appending file 433 of 524...
# 	Appending file 434 of 524...
# 	Appending file 435 of 524...
# 	Appending file 436 of 524...
# 	Appending file 437 of 524...
# 	Appending file 438 of 524...
# 	Appending file 439 of 524...
# 	Appending file 440 of 524...
# 	Appending file 441 of 524...
# 	Appending file 442 of 524...
# 	Appending file 443 of 524...
# 	Appending file 444 of 524...
# 	Appending file 445 of 524...
# 	Appending file 446 of 524...
# 	Appending file 447 of 524...
# 	Appending file 448 of 524...
# 	Appending file 449 of 524...
# 	Appending file 450 of 524...
# 	Appending file 451 of 524...
# 	Appending file 452 of 524...
# 	Appending file 453 of 524...
# 	Appending file 454 of 524...
# 	Appending file 455 of 524...
# 	Appending file 456 of 524...
# 	Appending file 457 of 524...
# 	Appending file 458 of 524...
# 	Appending file 459 of 524...
# 	Appending file 460 of 524...
# 	Appending file 461 of 524...
# 	Appending file 462 of 524...
# 	Appending file 463 of 524...
# 	Appending file 464 of 524...
# 	Appending file 465 of 524...
# 	Appending file 466 of 524...
# 	Appending file 467 of 524...
# 	Appending file 468 of 524...
# 	Appending file 469 of 524...
# 	Appending file 470 of 524...
# 	Appending file 471 of 524...
# 	Appending file 472 of 524...
# 	Appending file 473 of 524...
# 	Appending file 474 of 524...
# 	Appending file 475 of 524...
# 	Appending file 476 of 524...
# 	Appending file 477 of 524...
# 	Appending file 478 of 524...
# 	Appending file 479 of 524...
# 	Appending file 480 of 524...
# 	Appending file 481 of 524...
# 	Appending file 482 of 524...
# 	Appending file 483 of 524...
# 	Appending file 484 of 524...
# 	Appending file 485 of 524...
# 	Appending file 486 of 524...
# 	Appending file 487 of 524...
# 	Appending file 488 of 524...
# 	Appending file 489 of 524...
# 	Appending file 490 of 524...
# 	Appending file 491 of 524...
# 	Appending file 492 of 524...
# 	Appending file 493 of 524...
# 	Appending file 494 of 524...
# 	Appending file 495 of 524...
# 	Appending file 496 of 524...
# 	Appending file 497 of 524...
# 	Appending file 498 of 524...
# 	Appending file 499 of 524...
# 	Appending file 500 of 524...
# 	Appending file 501 of 524...
# 	Appending file 502 of 524...
# 	Appending file 503 of 524...
# 	Appending file 504 of 524...
# 	Appending file 505 of 524...
# 	Appending file 506 of 524...
# 	Appending file 507 of 524...
# 	Appending file 508 of 524...
# 	Appending file 509 of 524...
# 	Appending file 510 of 524...
# 	Appending file 511 of 524...
# 	Appending file 512 of 524...
# 	Appending file 513 of 524...
# 	Appending file 514 of 524...
# 	Appending file 515 of 524...
# 	Appending file 516 of 524...
# 	Appending file 517 of 524...
# 	Appending file 518 of 524...
# 	Appending file 519 of 524...
# 	Appending file 520 of 524...
# 	Appending file 521 of 524...
# 	Appending file 522 of 524...
# 	Appending file 523 of 524...
# 	Appending file 524 of 524...

# %% [markdown]
# ## Write concatenated data out to NetCDF

# %%
print('{}    Concatenation complete. Beginning netCDF write...'.format(dt.strftime(dt.now(),'%y/%m/%d %H:%M:%S')))
# Create a netCDF file to hold our output
rootGrp = Dataset(outFileName,'w',format='NETCDF4')
rootGrp.set_fill_on()

# Define the netCDF dimensions
gateRng = rootGrp.createDimension('gateRng',totalRng)
time1d = rootGrp.createDimension('time1d',totalTime)

# Create out output variable instances within the file and
#    define metadata for each as needed
TIME = rootGrp.createVariable('time1d','f8',('time1d',))
TIME.long_name = 'Timestamp'
TIME.units = 'UTC YYYYMMDDTHHMMSS.f'
TIME.coordinates = 'time1d'

GRNG = rootGrp.createVariable('gateRng','f4',('gateRng',),fill_value=np.nan)
GRNG.long_name = 'Distance from radar to center of each range gate'
GRNG.units = 'm'
GRNG.coordinates = 'gateRng'

TIME2D = rootGrp.createVariable('time2d','f8',('time1d','gateRng'))
TIME2D.long_name = 'Timestamp for every gate/time'
TIME2D.units = 'UTC YYYYMMDDTHHMMSS.f'
TIME2D.coordinates = 'time1d gateRng'

GALT2D = rootGrp.createVariable('gateAlt2d','f4',('time1d','gateRng'),fill_value=np.nan)
GALT2D.long_name = 'Altitude of each gate above MSL'
GALT2D.units = 'm'
GALT2D.coordinates = 'time1d gateRng'

ALT = rootGrp.createVariable('planeAlt','f4',('time1d',),fill_value=np.nan)
ALT.long_name = 'Aircraft altitude above MSL'
ALT.units = 'm'
ALT.coordinates = 'time1d'

DBZ = rootGrp.createVariable('DBZ','f4',('time1d','gateRng'),fill_value=np.nan)
DBZ.long_name = 'reflectivity'
DBZ.units = 'dBZ'
DBZ.sampling_ratio = 1.000000
DBZ.grid_mapping = 'grid_mapping'
DBZ.coordinates = 'time1d gateRng'

VEL = rootGrp.createVariable('VEL','f4',('time1d','gateRng'),fill_value=np.nan)
VEL.long_name = 'doppler_velocity'
VEL.units = 'm/s'
VEL.sampling_ratio = 1.000000
VEL.grid_mapping = 'grid_mapping'
VEL.coordinates = 'time1d gateRng'

WIDTH = rootGrp.createVariable('WIDTH','f4',('time1d','gateRng'),fill_value=np.nan)
WIDTH.long_name = 'spectrum_width'
WIDTH.units = 'm/s'
WIDTH.sampling_ratio = 1.000000
WIDTH.grid_mapping = 'grid_mapping'
WIDTH.coordinates = 'time1d gateRng'

LDR = rootGrp.createVariable('LDR','f4',('time1d','gateRng'),fill_value=np.nan)
LDR.long_name = 'linear_depolarization_ratio'
LDR.units = 'dB'
LDR.sampling_ratio = 1.000000
LDR.grid_mapping = 'grid_mapping'
LDR.coordinates = 'time1d gateRng'

NCP = rootGrp.createVariable('NCP','f4',('time1d','gateRng'),fill_value=np.nan)
NCP.long_name = 'normalized_coherent_power'
NCP.units = ''
NCP.sampling_ratio = 1.000000
NCP.grid_mapping = 'grid_mapping'
NCP.coordinates = 'time1d gateRng'

SNR = rootGrp.createVariable('SNR','f4',('time1d','gateRng'),fill_value=np.nan)
SNR.long_name = 'signal_to_noise_ratio'
SNR.units = 'dB'
SNR.sampling_ratio = 1.000000
SNR.grid_mapping = 'grid_mapping'
SNR.coordinates = 'time1d gateRng'

RELV = rootGrp.createVariable('elevation','f4',('time1d',),fill_value=np.nan)
RELV.long_name = 'Radar beam elevation (positive is upwards [plane-relative])'
RELV.units = 'degrees'
RELV.coordinates = 'time1d'


# Define global attributes
rootGrp.description = 'Concatenated HIAPER Cloud Radar data'
rootGrp.flight = flight
rootGrp.history = 'Created ' + time.asctime(time.gmtime()) + ' UTC'
rootGrp.firstFile = files[strtFIx]
rootGrp.lastFile = files[endFIx]

## Write data into netCDF variables
TIME[:] = time1d_all.astype(np.float64)
GRNG[:] = gateRange_1d
TIME2D[:] = time_all.astype(np.float64)
GALT2D[:] = alt_all
ALT[:] = alt1d_all
DBZ[:] = dbz_all
VEL[:] = vel_all
WIDTH[:] = width_all
LDR[:] = ldr_all
NCP[:] = ncp_all
SNR[:] = snr_all
RELV[:] = radElev_all

# Close the output file
rootGrp.close()

print('\nTotal script run time: {}'.format(dt.now() - scriptStrtT))
# Out:
# 18/02/01 13:39:48    Concatenation complete. Beginning netCDF write...
#
# Total script run time: 0:05:48.938956
